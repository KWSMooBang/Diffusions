# %%
import os
import sys
import matplotlib.pyplot as plt

from datasets import *
from torchvision.transforms import v2

tensor_to_pil = v2.ToPILImage()

# %% [markdown]
# ## CIFAR 10

# %%
cifar10 = Cifar10(
    root = os.path.join(os.getcwd(), 'cifar10'),
    image_size=256,
    train = True,
)

# %%
tensor_to_pil(cifar10[32])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ## CelebA

# %%
celebA = CelebA(
    root = os.path.join(os.getcwd(), 'celeba'),
    image_size=256
)

# %%
tensor_to_pil(celebA[10])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ## LSUN dataset

# %%
lsun = CustomLSUN(
    root = os.path.join(os.getcwd(), 'lsun'),
    classes=["bedroom_val"]
)

# %%
plt.imshow(lsun[0].numpy().transpose(1, 2, 0))
plt.axis('off')
plt.show()
